# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

PATH = "data/new_assigned_memes_final_merged.csv"
NO = "NO_TEMPLATE"

df = pd.read_csv(PATH, low_memory=False)
df["template_final"] = df["template_final"].fillna(NO).astype(str).str.strip()

# Exclude NO_TEMPLATE
df_valid = df[df["template_final"].ne(NO)].copy()

print("Total rows:", len(df))
print("Rows excluding NO_TEMPLATE:", len(df_valid))
print("Unique templates (excluding NO_TEMPLATE):", df_valid["template_final"].nunique())
# Out:
# Total rows: 171793
# Rows excluding NO_TEMPLATE: 94038
# Unique templates (excluding NO_TEMPLATE): 26936

# %%
tpl_counts = df_valid["template_final"].value_counts()

plt.figure(figsize=(12, 8))
sns.barplot(
    x=tpl_counts.head(20).values,
    y=tpl_counts.head(20).index,
    palette="viridis"
)
plt.title("Top 20 Template Frequencies (Excluding NO_TEMPLATE)")
plt.xlabel("Count")
plt.ylabel("Template")
plt.tight_layout()
plt.show()
# Out:
# /var/folders/q9/sf8tjzc130s4gxh60ngggj4w0000gn/T/ipykernel_39562/3780361147.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
meme_sub = pd.read_parquet("data/meme_submissions.zst.parquet")
meme_sub.columns
# Out:
# Index(['id', 'score', 'title', 'body', 'url', 'image_url', 'post_link',
#        'created_utc'],
#       dtype='object')

# %% [markdown]
# ## Clustering Code

# %%
from sentence_transformers import SentenceTransformer
from sklearn.cluster import AgglomerativeClustering

IN_PATH = "data/new_assigned_memes_final_merged.csv"
OUT_PATH = "data/new_assigned_memes_template_clustered.csv"
MAP_PATH = "data/template_cluster_mapping.csv"

NO = "NO_TEMPLATE"
TEMPLATE_COL = "template_final"
DIST_THRESHOLD = 0.20   # tune: lower=stricter, higher=more merges

# %%
df = pd.read_csv(IN_PATH, low_memory=False)
df[TEMPLATE_COL] = df[TEMPLATE_COL].fillna(NO).astype(str).str.strip()

# Exclude NO_TEMPLATE for clustering
df_non_no = df[df[TEMPLATE_COL].ne(NO)].copy()

print("Rows total:", len(df))
print("Rows (non-NO_TEMPLATE):", len(df_non_no))
print("Unique templates (non-NO_TEMPLATE):", df_non_no[TEMPLATE_COL].nunique())
# Out:
# Rows total: 171793
# Rows (non-NO_TEMPLATE): 93596
# Unique templates (non-NO_TEMPLATE): 26931

# %%
counts = df_non_no[TEMPLATE_COL].value_counts()
n_classes = counts.shape[0]

print("Classes:", n_classes)
print("Median per class:", int(counts.median()))
print("Classes >= 20:", int((counts >= 20).sum()))
print("Classes >= 50:", int((counts >= 50).sum()))
print("Classes >= 100:", int((counts >= 100).sum()))
display(counts.head(20).rename("count").to_frame())
# Out:
# Classes: 26931
# Median per class: 1
# Classes >= 20: 558
# Classes >= 50: 199
# Classes >= 100: 73
#                                      count
# template_final
# Drake Hotline Bling                   2163
# Two Buttons                           1312
# Mr. Incredible Becoming Uncanny        938
# Person Holding Sign                    901
# Expanding Brain                        711
# Distracted Boyfriend                   668
# Nobody:                                599
# Stonks                                 589
# Woman Yelling at a Cat                 481
# Me and the boys                        477
# Gru's Plan                             470
# Lisa Simpson Presentation              436
# Gigachad                               425
# UNO Draw 25                            384
# Vince McMahon Reaction                 380
# Disaster Girl                          363
# What Gives People Feelings of Power    357
# Trade Offer                            347
# Disappointed Black Guy                 316
# Monkey Puppet Looking Away             314

# %%
import re
SYN_MAP = {
    r"\bman\b": "person",
    r"\bguy\b": "person",
    r"\bwoman\b": "person",
    r"\bkid\b": "child",
    r"\bkids\b": "children",
    r"\bchange my mind\b": "person holding sign",
}

def normalize_template_name(s: str) -> str:
    s = str(s).strip().lower()
    s = s.replace("&", " and ")
    s = re.sub(r"[^a-z0-9\s]", " ", s)
    s = re.sub(r"\s+", " ", s).strip()
    for pat, repl in SYN_MAP.items():
        s = re.sub(pat, repl, s)
    s = re.sub(r"\s+", " ", s).strip()
    return s

tpl_df = (
    df_non_no[TEMPLATE_COL]
    .value_counts()
    .rename_axis("template")
    .reset_index(name="count")
)
tpl_df["template_norm"] = tpl_df["template"].map(normalize_template_name)

display(tpl_df.head(20))
# Out:
#                                template  count  \
# 0                   Drake Hotline Bling   2163
# 1                           Two Buttons   1312
# 2       Mr. Incredible Becoming Uncanny    938
# 3                   Person Holding Sign    901
# 4                       Expanding Brain    711
# 5                  Distracted Boyfriend    668
# 6                               Nobody:    599
# 7                                Stonks    589
# 8                Woman Yelling at a Cat    481
# 9                       Me and the boys    477
# 10                           Gru's Plan    470
# 11            Lisa Simpson Presentation    436
# 12                             Gigachad    425
# 13                          UNO Draw 25    384
# 14               Vince McMahon Reaction    380
# 15                        Disaster Girl    363
# 16  What Gives People Feelings of Power    357
# 17                          Trade Offer    347
# 18               Disappointed Black Guy    316
# 19           Monkey Puppet Looking Away    314
#
#                           template_norm
# 0                   drake hotline bling
# 1                           two buttons
# 2        mr incredible becoming uncanny
# 3                   person holding sign
# 4                       expanding brain
# 5                  distracted boyfriend
# 6                                nobody
# 7                                stonks
# 8               person yelling at a cat
# 9                       me and the boys
# 10                           gru s plan
# 11            lisa simpson presentation
# 12                             gigachad
# 13                          uno draw 25
# 14               vince mcmahon reaction
# 15                        disaster girl
# 16  what gives people feelings of power
# 17                          trade offer
# 18            disappointed black person
# 19           monkey puppet looking away

# %%
norm_groups = (
    tpl_df.groupby("template_norm", as_index=False)
    .agg(
        variants=("template", list),
        total_count=("count", "sum")
    )
)

print("Unique normalized groups:", len(norm_groups))
display(norm_groups.head(20))
# Out:
# Unique normalized groups: 23982
#                                        template_norm  \
# 0
# 1                            0 days without nonsense
# 2                                      0 drug 1 drug
# 3                       03 06 not great not terrible
# 4                                1 5 million peoples
# 5                                   1 in 10 dentists
# 6                                             1 in 4
# 7                                   1 million people
# 8                                        1 of people
# 9                                     1 of x 99 of y
# 10                              1 out of 10 dentists
# 11                                   10 4 good buddy
# 12  10 haunting photos taken moments before disaster
# 13                     10 out of 10 dentists approve
# 14                  10 out of 10 people die of death
# 15                                         10 person
# 16           10 photos taken moments before disaster
# 17                                 10 year challenge
# 18              10 year old me googling callipygeous
# 19                                     100 of people
#
#                                              variants  total_count
# 0                                   [Ñ, 🗿, ¯\_(ツ)_/¯]           21
# 1                           [0 Days Without Nonsense]            1
# 2                                     [0 drug 1 drug]            4
# 3                     [03:06 not great, not terrible]            4
# 4                              [1.5 million peoples:]            1
# 5                                  [1 in 10 dentists]            1
# 6                                            [1 in 4]            1
# 7                                 [1 million people:]            2
# 8                                      [1% of people]            1
# 9                                 [1% of X, 99% of Y]            1
# 10                             [1 out of 10 dentists]            1
# 11                                [10-4, GOOD BUDDY!]            1
# 12  [10 Haunting Photos Taken Moments Before Disas...            4
# 13                    [10 OUT OF 10 DENTISTS APPROVE]            2
# 14                 [10 OUT OF 10 PEOPLE DIE OF DEATH]            2
# 15                                           [10 Guy]           15
# 16          [10 photos taken moments before disaster]            1
# 17             [10 Year Challenge, 10 year challenge]            2
# 18             [10 year old me googling Callipygeous]            1
# 19                                   [100% OF PEOPLE]            1

# %%
model = SentenceTransformer("all-MiniLM-L6-v2")
emb = model.encode(
    norm_groups["template_norm"].tolist(),
    normalize_embeddings=True,
    show_progress_bar=True
)

print("Embedding shape:", emb.shape)
# Out:
# python(37642) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 1518.30it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Batches: 100%|██████████| 750/750 [00:13<00:00, 55.89it/s]
# Embedding shape: (23982, 384)

# %%
clusterer = AgglomerativeClustering(
    n_clusters=None,
    metric="cosine",
    linkage="average",
    distance_threshold=DIST_THRESHOLD
)
norm_groups["cluster_id"] = clusterer.fit_predict(emb)

print("Clusters:", norm_groups["cluster_id"].nunique())
display(norm_groups.sort_values(["cluster_id", "total_count"], ascending=[True, False]).head(30))
# Out:
# Clusters: 17981
#                            template_norm  \
# 17218              spongebob burn notice
# 17223           spongebob burning office
# 17415       spongebob in a fiery kitchen
# 17421          spongebob in burning room
# 17217                  spongebob burn it
# 17222                  spongebob burning
# 17418      spongebob in burning building
# 17419       spongebob in burning kitchen
# 17839        spongebob yeet it to flames
# 12090    mordecai and rigby giving gifts
# 12102   mordecai and rigby offering cake
# 21357                          vault boy
# 5997                   hold up vault boy
# 4191                   fallout vault boy
# 21360                  vault boy hold up
# 21359  vault boy excuse me what the fuck
# 21358                 vault boy charisma
# 17388           spongebob i need it meme
# 17377     spongebob i don t need it meme
# 17494                  spongebob me meme
# 17289       spongebob everyone else meme
# 17254            spongebob computer meme
# 17389              spongebob i need meme
# 17741               spongebob texas meme
# 17840                 spongebob yep meme
# 17233           spongebob can i get meme
# 17266                 spongebob cum meme
# 17282                  spongebob e3 meme
# 17291            spongebob everyone meme
# 17303               spongebob facts meme
#
#                                                 variants  total_count  \
# 17218                            [SpongeBob Burn Notice]            4
# 17223                         [SpongeBob Burning Office]            2
# 17415                     [SpongeBob in a fiery kitchen]            2
# 17421  [Spongebob in Burning Room, SpongeBob in Burni...            2
# 17217                                [SpongeBob Burn It]            1
# 17222                                [SpongeBob Burning]            1
# 17418                    [SpongeBob in burning building]            1
# 17419                     [Spongebob in burning kitchen]            1
# 17839                    [SpongeBob "Yeet it to flames"]            1
# 12090                  [Mordecai and Rigby giving gifts]            1
# 12102                 [Mordecai and Rigby offering cake]            1
# 21357                                        [Vault Boy]            6
# 5997                                 [Hold Up Vault Boy]            5
# 4191                                 [Fallout Vault Boy]            3
# 21360           [Vault Boy "Hold Up", Vault Boy Hold Up]            3
# 21359  [Vault Boy "Excuse Me What The Fuck", Vault Bo...            2
# 21358                               [Vault Boy Charisma]            1
# 17388                       [SpongeBob "I Need It" Meme]            6
# 17377                 [SpongeBob "I Don't Need It" Meme]            4
# 17494                              [SpongeBob "Me" Meme]            4
# 17289                   [SpongeBob "Everyone Else" Meme]            3
# 17254  [SpongeBob Computer Meme, Spongebob Computer M...            2
# 17389                       [SpongeBob "I Need..." Meme]            2
# 17741                             [SpongeBob Texas Meme]            2
# 17840                             [SpongeBob "Yep" Meme]            2
# 17233                       [SpongeBob "Can I Get" Meme]            1
# 17266                             [SpongeBob "Cum" Meme]            1
# 17282                                [SpongeBob E3 Meme]            1
# 17291                        [SpongeBob "Everyone" Meme]            1
# 17303                           [SpongeBob "Facts" Meme]            1
#
#        cluster_id
# 17218           0
# 17223           0
# 17415           0
# 17421           0
# 17217           0
# 17222           0
# 17418           0
# 17419           0
# 17839           0
# 12090           1
# 12102           1
# 21357           2
# 5997            2
# 4191            2
# 21360           2
# 21359           2
# 21358           2
# 17388           3
# 17377           3
# 17494           3
# 17289           3
# 17254           3
# 17389           3
# 17741           3
# 17840           3
# 17233           3
# 17266           3
# 17282           3
# 17291           3
# 17303           3

# %%
count_lookup = dict(zip(tpl_df["template"], tpl_df["count"]))

rows = []
for r in norm_groups.itertuples(index=False):
    for v in r.variants:
        rows.append({
            "cluster_id": r.cluster_id,
            "template": v,
            "count": count_lookup.get(v, 0)
        })
variant_df = pd.DataFrame(rows)

canonical = (
    variant_df.sort_values(["cluster_id", "count"], ascending=[True, False])
    .groupby("cluster_id", as_index=False)
    .first()
    .rename(columns={"template": "canonical_template"})
)

cluster_map = norm_groups.merge(canonical[["cluster_id", "canonical_template"]], on="cluster_id", how="left")
display(cluster_map.head(20))
# Out:
#                                        template_norm  \
# 0
# 1                            0 days without nonsense
# 2                                      0 drug 1 drug
# 3                       03 06 not great not terrible
# 4                                1 5 million peoples
# 5                                   1 in 10 dentists
# 6                                             1 in 4
# 7                                   1 million people
# 8                                        1 of people
# 9                                     1 of x 99 of y
# 10                              1 out of 10 dentists
# 11                                   10 4 good buddy
# 12  10 haunting photos taken moments before disaster
# 13                     10 out of 10 dentists approve
# 14                  10 out of 10 people die of death
# 15                                         10 person
# 16           10 photos taken moments before disaster
# 17                                 10 year challenge
# 18              10 year old me googling callipygeous
# 19                                     100 of people
#
#                                              variants  total_count  \
# 0                                   [Ñ, 🗿, ¯\_(ツ)_/¯]           21
# 1                           [0 Days Without Nonsense]            1
# 2                                     [0 drug 1 drug]            4
# 3                     [03:06 not great, not terrible]            4
# 4                              [1.5 million peoples:]            1
# 5                                  [1 in 10 dentists]            1
# 6                                            [1 in 4]            1
# 7                                 [1 million people:]            2
# 8                                      [1% of people]            1
# 9                                 [1% of X, 99% of Y]            1
# 10                             [1 out of 10 dentists]            1
# 11                                [10-4, GOOD BUDDY!]            1
# 12  [10 Haunting Photos Taken Moments Before Disas...            4
# 13                    [10 OUT OF 10 DENTISTS APPROVE]            2
# 14                 [10 OUT OF 10 PEOPLE DIE OF DEATH]            2
# 15                                           [10 Guy]           15
# 16          [10 photos taken moments before disaster]            1
# 17             [10 Year Challenge, 10 year challenge]            2
# 18             [10 year old me googling Callipygeous]            1
# 19                                   [100% OF PEOPLE]            1
#
#     cluster_id                                canonical_template
# 0        16257                                                 Ñ
# 1        10393                           0 Days Without Nonsense
# 2        15739                                     0 drug 1 drug
# 3         9143                     03:06 not great, not terrible
# 4         3261                                 1 million people:
# 5         1263                                     9/10 Dentists
# 6        12540                                            1 in 4
# 7         3261                                 1 million people:
# 8        12968                                      1% of people
# 9        12205                                 1% of X, 99% of Y
# 10        1263                                     9/10 Dentists
# 11       16003                                 10-4, GOOD BUDDY!
# 12        1566  10 Haunting Photos Taken Moments Before Disaster
# 13       16945                     10 OUT OF 10 DENTISTS APPROVE
# 14       14909                  10 OUT OF 10 PEOPLE DIE OF DEATH
# 15       10174                                            10 Guy
# 16        1566  10 Haunting Photos Taken Moments Before Disaster
# 17        9828                                 10 Year Challenge
# 18       11663              10 year old me googling Callipygeous
# 19       14012                                    100% OF PEOPLE

# %%
template_to_canonical = {}
for r in cluster_map.itertuples(index=False):
    for v in r.variants:
        template_to_canonical[v] = r.canonical_template

mapping_df = pd.DataFrame({
    "template_original": list(template_to_canonical.keys()),
    "template_clustered": list(template_to_canonical.values())
}).sort_values(["template_clustered", "template_original"])

display(mapping_df.head(50))
# Out:
#                                        template_original  \
# 6638                                        "hits blunt"
# 24                                     #10YEARSCHALLENGE
# 4607                                #explainafilmotbadly
# 4835                                 #firstworldproblems
# 3                                0 Days Without Nonsense
# 4                                          0 drug 1 drug
# 5                          03:06 not great, not terrible
# 8                                                 1 in 4
# 9                                      1 million people:
# 6                                   1.5 million peoples:
# 11                                     1% of X, 99% of Y
# 10                                          1% of people
# 17                                                10 Guy
# 14      10 Haunting Photos Taken Moments Before Disaster
# 18               10 photos taken moments before disaster
# 108                     4 pictures taken before disaster
# 16302               Photos Taken Moments Before Disaster
# 16317             Pictures Taken Moments Before Disaster
# 15                         10 OUT OF 10 DENTISTS APPROVE
# 16                      10 OUT OF 10 PEOPLE DIE OF DEATH
# 19                                     10 Year Challenge
# 20                                     10 year challenge
# 21                  10 year old me googling Callipygeous
# 13                                     10-4, GOOD BUDDY!
# 22                                        100% OF PEOPLE
# 23                                      101% wait wtf?!?
# 27                                        11 year old me
# 25                                              11+10=21
# 26      11-year-old in real life / in anime / on Netflix
# 29                                          12 Angry Men
# 28                 12,000 years and nothing has changed.
# 30                              12-Character Zodiac Meme
# 31                                        13 Reasons Why
# 34                           13 Reasons Why "That Smile"
# 33       13 Reasons Why "That's Where The Trouble Began"
# 32                              13 Reasons Why Is Gamora
# 35                               14 M PEOPLE: I am Dream
# 36                                     14-Year-Old Girls
# 37                                         144p vs 1080p
# 144                                        720p vs 1080p
# 38                                            144p vs 4k
# 39                             14yo White girls be like:
# 40                     15 Minutes of Useless Information
# 41                 16 reasons why a wife needs a husband
# 42                                16 years of difference
# 43                                        192742 People:
# 44     1969: In the future, we'll have flying cars an...
# 45                                      1984 Big Brother
# 46                                           1989 vs Now
# 50                   2 IN THE THOUGHTS, 1 IN THE PRAYERS
#
#                                       template_clustered
# 6638                                        "hits blunt"
# 24                                     #10YEARSCHALLENGE
# 4607                                #explainafilmotbadly
# 4835                                 #firstworldproblems
# 3                                0 Days Without Nonsense
# 4                                          0 drug 1 drug
# 5                          03:06 not great, not terrible
# 8                                                 1 in 4
# 9                                      1 million people:
# 6                                      1 million people:
# 11                                     1% of X, 99% of Y
# 10                                          1% of people
# 17                                                10 Guy
# 14      10 Haunting Photos Taken Moments Before Disaster
# 18      10 Haunting Photos Taken Moments Before Disaster
# 108     10 Haunting Photos Taken Moments Before Disaster
# 16302   10 Haunting Photos Taken Moments Before Disaster
# 16317   10 Haunting Photos Taken Moments Before Disaster
# 15                         10 OUT OF 10 DENTISTS APPROVE
# 16                      10 OUT OF 10 PEOPLE DIE OF DEATH
# 19                                     10 Year Challenge
# 20                                     10 Year Challenge
# 21                  10 year old me googling Callipygeous
# 13                                     10-4, GOOD BUDDY!
# 22                                        100% OF PEOPLE
# 23                                      101% wait wtf?!?
# 27                                        11 year old me
# 25                                              11+10=21
# 26      11-year-old in real life / in anime / on Netflix
# 29                                          12 Angry Men
# 28                 12,000 years and nothing has changed.
# 30                              12-Character Zodiac Meme
# 31                                        13 Reasons Why
# 34                           13 Reasons Why "That Smile"
# 33       13 Reasons Why "That's Where The Trouble Began"
# 32                              13 Reasons Why Is Gamora
# 35                               14 M PEOPLE: I am Dream
# 36                                     14-Year-Old Girls
# 37                                         144p vs 1080p
# 144                                        144p vs 1080p
# 38                                            144p vs 4k
# 39                             14yo White girls be like:
# 40                     15 Minutes of Useless Information
# 41                 16 reasons why a wife needs a husband
# 42                                16 years of difference
# 43                                        192742 People:
# 44     1969: In the future, we'll have flying cars an...
# 45                                      1984 Big Brother
# 46                                           1989 vs Now
# 50                   2 IN THE THOUGHTS, 1 IN THE PRAYERS

# %%
import numpy as np
df["template_clustered"] = np.where(
    df[TEMPLATE_COL].eq(NO),
    NO,
    df[TEMPLATE_COL].map(template_to_canonical).fillna(df[TEMPLATE_COL])
)

print("Unique before:", df[TEMPLATE_COL].nunique())
print("Unique after:", df["template_clustered"].nunique())

display(
    df[[TEMPLATE_COL, "template_clustered"]]
    .drop_duplicates()
    .sort_values(["template_clustered", TEMPLATE_COL])
    .head(60)
)
# Out:
# Unique before: 26932
# Unique after: 17982
#                                            template_final  \
# 75969                                        "hits blunt"
# 41282                                   #10YEARSCHALLENGE
# 49349                                #explainafilmotbadly
# 90836                                 #firstworldproblems
# 452                               0 Days Without Nonsense
# 88457                                       0 drug 1 drug
# 12382                       03:06 not great, not terrible
# 94659                                              1 in 4
# 62839                                   1 million people:
# 69753                                1.5 million peoples:
# 59250                                   1% of X, 99% of Y
# 90357                                        1% of people
# 6047                                               10 Guy
# 57429    10 Haunting Photos Taken Moments Before Disaster
# 38154             10 photos taken moments before disaster
# 35888                    4 pictures taken before disaster
# 152930               Photos Taken Moments Before Disaster
# 54314              Pictures Taken Moments Before Disaster
# 18193                       10 OUT OF 10 DENTISTS APPROVE
# 79749                    10 OUT OF 10 PEOPLE DIE OF DEATH
# 98459                                   10 Year Challenge
# 10727                                   10 year challenge
# 30290                10 year old me googling Callipygeous
# 162527                                  10-4, GOOD BUDDY!
# 169003                                     100% OF PEOPLE
# 70390                                    101% wait wtf?!?
# 102820                                     11 year old me
# 83466                                            11+10=21
# 96901    11-year-old in real life / in anime / on Netflix
# 44670                                        12 Angry Men
# 24955               12,000 years and nothing has changed.
# 17996                            12-Character Zodiac Meme
# 75016                                      13 Reasons Why
# 50810                         13 Reasons Why "That Smile"
# 153287    13 Reasons Why "That's Where The Trouble Began"
# 114952                           13 Reasons Why Is Gamora
# 128343                            14 M PEOPLE: I am Dream
# 7971                                    14-Year-Old Girls
# 78735                                       144p vs 1080p
# 84475                                       720p vs 1080p
# 99342                                          144p vs 4k
# 84153                           14yo White girls be like:
# 13075                   15 Minutes of Useless Information
# 99616               16 reasons why a wife needs a husband
# 34506                              16 years of difference
# 78306                                      192742 People:
# 16361   1969: In the future, we'll have flying cars an...
# 11248                                    1984 Big Brother
# 153157                                        1989 vs Now
# 118127                2 IN THE THOUGHTS, 1 IN THE PRAYERS
# 105713                                   2 Million People
# 27950                                 2.4 million people:
# 51259                                 2.9 million people:
# 8854                                 2 Redditors discuss:
# 171685                                    2 Seconds Later
# 45864                                          2 types of
# 58894                                               2+2=4
# 117466  200,000 thoughts are ready, with a million mor...
# 151905  200,000 ready, with a million more well on the...
# 3909    200,000 units are ready, with a million more w...
#
#                                        template_clustered
# 75969                                        "hits blunt"
# 41282                                   #10YEARSCHALLENGE
# 49349                                #explainafilmotbadly
# 90836                                 #firstworldproblems
# 452                               0 Days Without Nonsense
# 88457                                       0 drug 1 drug
# 12382                       03:06 not great, not terrible
# 94659                                              1 in 4
# 62839                                   1 million people:
# 69753                                   1 million people:
# 59250                                   1% of X, 99% of Y
# 90357                                        1% of people
# 6047                                               10 Guy
# 57429    10 Haunting Photos Taken Moments Before Disaster
# 38154    10 Haunting Photos Taken Moments Before Disaster
# 35888    10 Haunting Photos Taken Moments Before Disaster
# 152930   10 Haunting Photos Taken Moments Before Disaster
# 54314    10 Haunting Photos Taken Moments Before Disaster
# 18193                       10 OUT OF 10 DENTISTS APPROVE
# 79749                    10 OUT OF 10 PEOPLE DIE OF DEATH
# 98459                                   10 Year Challenge
# 10727                                   10 Year Challenge
# 30290                10 year old me googling Callipygeous
# 162527                                  10-4, GOOD BUDDY!
# 169003                                     100% OF PEOPLE
# 70390                                    101% wait wtf?!?
# 102820                                     11 year old me
# 83466                                            11+10=21
# 96901    11-year-old in real life / in anime / on Netflix
# 44670                                        12 Angry Men
# 24955               12,000 years and nothing has changed.
# 17996                            12-Character Zodiac Meme
# 75016                                      13 Reasons Why
# 50810                         13 Reasons Why "That Smile"
# 153287    13 Reasons Why "That's Where The Trouble Began"
# 114952                           13 Reasons Why Is Gamora
# 128343                            14 M PEOPLE: I am Dream
# 7971                                    14-Year-Old Girls
# 78735                                       144p vs 1080p
# 84475                                       144p vs 1080p
# 99342                                          144p vs 4k
# 84153                           14yo White girls be like:
# 13075                   15 Minutes of Useless Information
# 99616               16 reasons why a wife needs a husband
# 34506                              16 years of difference
# 78306                                      192742 People:
# 16361   1969: In the future, we'll have flying cars an...
# 11248                                    1984 Big Brother
# 153157                                        1989 vs Now
# 118127                2 IN THE THOUGHTS, 1 IN THE PRAYERS
# 105713                                   2 Million People
# 27950                                    2 Million People
# 51259                                    2 Million People
# 8854                                 2 Redditors discuss:
# 171685                                    2 Seconds Later
# 45864                                          2 types of
# 58894                                               2+2=4
# 117466  200,000 thoughts are ready, with a million mor...
# 151905  200,000 units are ready, with a million more w...
# 3909    200,000 units are ready, with a million more w...

# %%
# Cell 11: Save outputs
df.to_csv(OUT_PATH, index=False)
mapping_df.to_csv(MAP_PATH, index=False)

print("Saved:", OUT_PATH)
print("Saved:", MAP_PATH)
# Out:
# Saved: data/new_assigned_memes_template_clustered.csv
# Saved: data/template_cluster_mapping.csv

# %%
audit = (
    mapping_df.groupby("template_clustered", as_index=False)
    .agg(n_original_labels=("template_original", "nunique"))
    .sort_values("n_original_labels", ascending=False)
)

display(audit.head(20))
# Out:
#                                       template_clustered  n_original_labels
# 9269                              Mom: We have X at home                 75
# 6276                           It is Wednesday, my dudes                 50
# 12905                         SpongeBob "I Need It" Meme                 45
# 14793  Therapist: [X] isn't real, he can't hurt you. ...                 36
# 7059                                     Kermit the Frog                 34
# 13157                              SpongeBob and Patrick                 29
# 14485                       The Undertaker and AJ Styles                 27
# 17643    You vs the guy she tells you not to worry about                 25
# 5306               I bet he's thinking about other women                 24
# 3731   Gentlemen, it is with great pleasure to inform...                 22
# 10223                     Obama awarding himself a medal                 22
# 13176                            SpongeBob and Squidward                 22
# 10237               Obi-Wan Kenobi "That's why I'm here"                 20
# 17083                                      Wojak vs Chad                 20
# 8903                                            Megamind                 19
# 9365                    Mordecai and Rigby opening a box                 19
# 266                                After all... why not?                 18
# 13104                          SpongeBob Sitting at Desk                 18
# 1608                           Buzz Lightyear Explaining                 18
# 590              And at this point I'm too afraid to ask                 17
